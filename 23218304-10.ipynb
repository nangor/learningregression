# %%
import numpy as np

num_points = 1000
x_data = np.random.normal(0, 0.55, num_points)
y_data = 0.1 * x_data + 0.3 + np.random.normal(0, 0.03, num_points)

# %%
import matplotlib.pyplot as plt

plt.plot(x_data, y_data, 'r.')
plt.show()

# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

for step in range(10):
    sess.run(train)
    print(step, sess.run(W), sess.run(b), sess.run(loss))
    
    # Plot Distribution of Points (x, y)
    plt.plot(x_data, y_data, 'r.')
    
    # Draw Regression Line
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    
    plt.xlim(-2,2)
    plt.ylim(0.1,0.6) 
    plt.show()
# Out:
# 0 [-0.5925056] [0.2964629] 0.1364372
# 1 [-0.39677185] [0.297474] 0.07064166
# 2 [-0.25636625] [0.2982034] 0.036785774
# 3 [-0.15564917] [0.29872662] 0.019364834
# 4 [-0.08340181] [0.29910195] 0.010400682
# 5 [-0.03157666] [0.29937118] 0.0057880725
# 6 [0.00559907] [0.2995643] 0.0034145995
# 7 [0.03226632] [0.29970285] 0.0021933008
# 8 [0.05139553] [0.2998022] 0.001564867
# 9 [0.06511748] [0.2998735] 0.0012414992
