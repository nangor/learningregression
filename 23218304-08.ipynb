# %%
import numpy as np

num_points = 1000
x_data = np.random.normal(0, 0.55, num_points)
y_data = 0.1 * x_data + 0.3 + np.random.normal(0, 0.03, num_points)

# %%
import matplotlib.pyplot as plt

plt.plot(x_data, y_data, 'r.')
plt.show()

# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

for step in range(8):
    sess.run(train)
    print(step, sess.run(W), sess.run(b), sess.run(loss))
    
    # Plot Distribution of Points (x, y)
    plt.plot(x_data, y_data, 'r.')
    
    # Draw Regression Line
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    
    plt.xlim(-2,2)
    plt.ylim(0.1,0.6) 
    plt.show()
# Out:
# 0 [0.01323426] [0.30148986] 0.0031096959
# 1 [0.03891079] [0.30136648] 0.0019878454
# 2 [0.05692493] [0.3012831] 0.0014356556
# 3 [0.06956328] [0.3012246] 0.0011638601
# 4 [0.07843008] [0.30118355] 0.0010300787
# 5 [0.08465084] [0.30115476] 0.00096422987
# 6 [0.08901521] [0.30113456] 0.00093181815
# 7 [0.09207715] [0.3011204] 0.0009158644
