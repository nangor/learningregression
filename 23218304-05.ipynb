# %%
import numpy as np

num_points = 1000
x_data = np.random.normal(0, 0.55, num_points)
y_data = 0.1 * x_data + 0.3 + np.random.normal(0, 0.03, num_points)

# %%
import matplotlib.pyplot as plt

plt.plot(x_data, y_data, 'r.')
plt.show()

# %%
import tensorflow.compat.v1 as tf

tf.disable_v2_behavior()

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0))
b = tf.Variable(tf.zeros([1]))
y = W * x_data + b

loss = tf.reduce_mean(tf.square(y - y_data))
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)

for step in range(5):
    sess.run(train)
    print(step, sess.run(W), sess.run(b), sess.run(loss))
    
    # Plot Distribution of Points (x, y)
    plt.plot(x_data, y_data, 'r.')
    
    # Draw Regression Line
    plt.plot(x_data, sess.run(W) * x_data + sess.run(b))
    
    plt.xlim(-2,2)
    plt.ylim(0.1,0.6) 
    plt.show()
# Out:
# 0 [-0.26537424] [0.2993321] 0.039130777
# 1 [-0.1595712] [0.29965714] 0.020021074
# 2 [-0.08476014] [0.2998884] 0.010466989
# 3 [-0.03186286] [0.3000519] 0.005690329
# 4 [0.00553967] [0.30016753] 0.0033021907
